# %%
import pandas as pd

# 读取CSV文件
df = pd.read_csv('wmt_zh_en_training_corpus.csv')

# 查看数据
print(df.head())  # 前5行
print(df.info())  # 数据信息
print(df.describe())  # 统计摘要
# Out:
#                                                    0  \
# 0  表演 的 明星 是 X 女孩 团队 — — 由 一对 具有 天才 技艺 的 艳舞 女孩 们 ...
# 1  表演 的 压轴戏 是 闹剧 版 《 天鹅湖 》 ， 男女 小 人们 身着 粉红色 的 芭蕾舞...
# 2     表演 和 后期制作 之间 的 屏障 被 清除 了 ， 这 对 演员 来说 一样 大有裨益 。
# 3   （ 表演 或 背诵 时 ） 通过 暗示 下面 忘记 或 记地 不准 的 东西 来 帮助 某人 。
# 4              表演 基本上 很 精彩 - - 我 只 对 她 的 技巧 稍 有 意见 。
#
#                                                    1
# 0  the show stars the X Girls - a troupe of talen...
# 1  the centerpiece of the show is a farcical rend...
# 2  the removal of the barrier between performance...
# 3  assist ( somebody acting or reciting ) by sugg...
# 4  basically it was a fine performance I have onl...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24752392 entries, 0 to 24752391
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   0       object
#  1   1       object
# dtypes: object(2)
# memory usage: 377.7+ MB
# None
#                0         1
# count   24752355  24752392
# ...
